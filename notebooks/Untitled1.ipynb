# %%
import sys
sys.path.append("/home/evangelos/workspace/Synthesis/FlowMonitoringAndAnalysis/")

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.streaming_utils import camera
import cv2
import matplotlib.pyplot as plt

# %%
v_cam = camera.VideoCamera()

# %%
frame = v_cam.get_frame()

# %%
type(v_cam.get_frame_bytes().tostring())
# Out:
# bytes

# %%
plt.imshow(frame)

# %%
data = v_cam.get_frame_bytes()

# %%
data + bytes(len(data))
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xdb\x00C\x01\x02\x02\x02\x02\x02\x02\x05\x03\x03\x05\n\x07\x06\x07\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xff\xc0\x00\x11\x08\x048\x07\x80\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\x83\x84\x85\x86\x87\x88\x89\x8a\x92\x93\x94\x95\x96\x97\x
# ...

# %%
len(data)
# Out:
# 468936

# %%
array = np.frombuffer(data, np.uint8)

# %%
frame = cv2.imdecode(array, cv2.COLOR_RGB2BGR)

# %%
frame.shape

# %%
plt.imshow(frame)

# %%
grey = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)

# %%
plt.imshow(frame[:,:,2])

# %%
plt.imshow(grey[:,:,2])

# %%
ret  = True
i = 0
while ret:
    ret, _ = v_cam.video.read()
    i +=1

# %%
v_cam.video.read()[1].shape

# %%
import pandas as pd
import csv

# %%
with open("../src/streaming_utils/labels.csv" ,"r") as f:
    reader = csv.reader(f)
    labels = list(reader)

# %%
with open("../src/streaming_utils/raw.csv" ,"r") as f:
    reader = csv.reader(f)
    raw = list(reader)

# %%
raw
